# %%
import pandas as pd
import numpy as np

s = pd.Series(np.random.rand(4))
s
# Out:
# 0    0.066174
# 1    0.999857
# 2    0.027840
# 3    0.440500
# dtype: float64

# %%
s = pd.Series(np.random.rand(4), index=['a', 'b', 'c', 'd'])
s
# Out:
# a    0.645883
# b    0.109056
# c    0.635976
# d    0.794591
# dtype: float64

# %%
s['c']
# Out:
# 0.635975821178474

# %%
mon_dic = {'US':'dollar', 'UK':'pound', 'Germany':'euro', 'Mexico':'peso', 'Nigeria':'naira','China':'yuan', 'Japan':'yen'}
mon_dic
# Out:
# {'US': 'dollar',
#  'UK': 'pound',
#  'Germany': 'euro',
#  'Mexico': 'peso',
#  'Nigeria': 'naira',
#  'China': 'yuan',
#  'Japan': 'yen'}

# %%
mon_dic_series = pd.Series(mon_dic)

# %%
mon_dic_series
# Out:
# US         dollar
# UK          pound
# Germany      euro
# Mexico       peso
# Nigeria     naira
# China        yuan
# Japan         yen
# dtype: object

# %% [markdown]
# ### Series avec NaN

# %%
prix_produit = {'Riz':25000, 'Sucre':1000, 'LAIT':1500, 'Savon':1600, 'Cafe':1000, 'Gaz':4000}
prix_produit_series = pd.Series(prix_produit,  index=['Riz', 'Sucre', 'Banane', 'LAIT', 'Savon', 'Cafe', 'Gaz'])

# %%
prix_produit_series
# Out:
# Riz       25000.0
# Sucre      1000.0
# Banane        NaN
# LAIT       1500.0
# Savon      1600.0
# Cafe       1000.0
# Gaz        4000.0
# dtype: float64

# %% [markdown]
# ### Valeurs Scalaires

# %%
chien_main = pd.Series('Chihuahua', index=['race', 'incertaine', 'nom'])
chien_main
# Out:
# race          Chihuahua
# incertaine    Chihuahua
# nom           Chihuahua
# dtype: object

# %%
maserie = pd.Series('Pythonista')
maserie
# Out:
# 0    Pythonista
# dtype: object

# %% [markdown]
# ### Opération sur les series

# %%
mon_dic['US'] = 'FCFA'

# %%
mon_dic
# Out:
# {'US': 'FCFA',
#  'UK': 'pound',
#  'Germany': 'euro',
#  'Mexico': 'peso',
#  'Nigeria': 'naira',
#  'China': 'yuan',
#  'Japan': 'yen'}

# %%
mon_dic.get('EDACY', np.NaN)
# Out:
# nan

# %%
prix_produit_series[:4]
# Out:
# Riz       25000.0
# Sucre      1000.0
# Banane        NaN
# LAIT       1500.0
# dtype: float64

# %%
prix_produit_series[prix_produit_series > 1000]
# Out:
# Riz      25000.0
# LAIT      1500.0
# Savon     1600.0
# Gaz       4000.0
# dtype: float64

# %% [markdown]
# # DataFrame

# %%
data = {'Année':[2000, 2005, 2010, 2014],
        'AgeMoyennne':[14.2, 26.4, 28.5, 30.3],
        'Densite':[244, 256, 268, 279]}
pdf = pd.DataFrame(data)

# %%
pdf
# Out:
#    Année  AgeMoyennne  Densite
# 0   2000         14.2      244
# 1   2005         26.4      256
# 2   2010         28.5      268
# 3   2014         30.3      279

# %%
pdf_lists_imbrique = pd.DataFrame([
    ['Amadou Fall', 16, 'Sénégal', 'Dakar', 'M', None],
    ['Aminata Maiga', 8, 'Mali', 'Bamako', 'F', None],
    ['Ibrahima Sory Konté', 25, 'Guinée', 'Conakry', 'M', None],
    ['Joseph Tabo', 35, 'Ghana', 'Koumasi', 'M', None]],
    columns=['Nom', 'Age', 'Pays','Ville', 'Sexe', 'Primé'])

# %%
pdf_lists_imbrique
# Out:
#                    Nom  Age     Pays    Ville Sexe Primé
# 0          Amadou Fall   16  Sénégal    Dakar    M  None
# 1        Aminata Maiga    8     Mali   Bamako    F  None
# 2  Ibrahima Sory Konté   25   Guinée  Conakry    M  None
# 3          Joseph Tabo   35    Ghana  Koumasi    M  None

# %% [markdown]
# # Indexation

# %% [markdown]
# df = pd.read_csv('D:/Jeu de données/Edacy/Pandas/nba-2.csv')

# %%
df
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
resultat = df['Name']

# %%
resultat
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
resultat = df[['Name', 'Age', 'Salary']]

# %%
resultat
# Out:
#                         Name   Age      Salary
# 0              Avery Bradley  25.0   7730337.0
# 1                Jae Crowder  25.0   6796117.0
# 2               John Holland  27.0         NaN
# 3                R.J. Hunter  22.0   1148640.0
# 4              Jonas Jerebko  29.0   5000000.0
# 5               Amir Johnson  29.0  12000000.0
# 6              Jordan Mickey  21.0   1170960.0
# 7               Kelly Olynyk  25.0   2165160.0
# 8               Terry Rozier  22.0   1824360.0
# 9               Marcus Smart  22.0   3431040.0
# 10           Jared Sullinger  24.0   2569260.0
# 11             Isaiah Thomas  27.0   6912869.0
# 12               Evan Turner  27.0   3425510.0
# 13               James Young  20.0   1749840.0
# 14              Tyler Zeller  26.0   2616975.0
# 15          Bojan Bogdanovic  27.0   3425510.0
# 16              Markel Brown  24.0    845059.0
# 17           Wayne Ellington  28.0   1500000.0
# 18   Rondae Hollis-Jefferson  21.0   1335480.0
# ...

# %%
resultat2 = df.get('Edacy', 'Valeur Inconnue')

# %%
resultat2
# Out:
# 'Valeur Inconnue'

# %%
df.Name
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
data = {'Almadies': {'Polualtions': '211 315', 'Superficie':30.1},
        'Dakar Plateau': {'Polualtions': '189 486', 'Superficie':14.7},
        'Grand Dakar': {'Polualtions': '306 728', 'Superficie':18.9},
        'Parcelles Assainies': {'Polualtions': '438 527', 'Superficie':14.7}
    
}

# %%
arrondissements_dakar = pd.DataFrame(data, columns=['Almadies', 'Dakar Plateau', 'Grand Dakar', 'Parcelles Assainies'])

# %%
arrondissements_dakar
# Out:
#             Almadies Dakar Plateau Grand Dakar Parcelles Assainies
# Polualtions  211 315       189 486     306 728             438 527
# Superficie      30.1          14.7        18.9                14.7

# %%
arrondissements_dakar.columns = ['Almadies', 'Dakar_Plateau', 'Grand_Dakar', 'Parcelles_Assainies']

# %%
arrondissements_dakar
# Out:
#             Almadies Dakar_Plateau Grand_Dakar Parcelles_Assainies
# Polualtions  211 315       189 486     306 728             438 527
# Superficie      30.1          14.7        18.9                14.7

# %%
arrondissements_dakar.Dakar_Plateau
# Out:
# Polualtions    189 486
# Superficie        14.7
# Name: Dakar_Plateau, dtype: object

# %%
data = {'Arrondissement':['Almadies', 'Dakar Plateau', 'Grand Dakar', 'Parcelles Assainies'],
        'Poulation en 2013': [211315, 189486,306728, 438527],
        'Superficie en Km2': [30.1, 14.7, 18.9, 14.7],
        'Communes d\'arrondissement': ['Mermoz . Sacré-Coeur . Ngor . Ouakam-Yoff',
                                        'Dakar-Plateau . Fann . PointE . Amitie-Geule-Tapé . Fass . Colobane . Medina',
                                        'Biscuiterie . Dieupeul . Derklé . Grand-Dakar . Hann-Bel-Air . Hlm . Sicap',
                                        'Camberene . Grand-Yoff . Parcelles-Assainies . Patte-D\'oie'
                                       ]
        
    
}

# %%
result  = pd.DataFrame(data, columns=['Arrondissement', 'Poulation en 2013', 'Superficie en Km2', 'Communes d\'arrondissement'])

# %%
result
# Out:
#         Arrondissement  Poulation en 2013  Superficie en Km2  \
# 0             Almadies             211315               30.1
# 1        Dakar Plateau             189486               14.7
# 2          Grand Dakar             306728               18.9
# 3  Parcelles Assainies             438527               14.7
#
#                            Communes d'arrondissement
# 0          Mermoz . Sacré-Coeur . Ngor . Ouakam-Yoff
# 1  Dakar-Plateau . Fann . PointE . Amitie-Geule-T...
# 2  Biscuiterie . Dieupeul . Derklé . Grand-Dakar ...
# 3  Camberene . Grand-Yoff . Parcelles-Assainies ....

# %%
result[:2]
# Out:
#   Arrondissement  Poulation en 2013  Superficie en Km2  \
# 0       Almadies             211315               30.1
# 1  Dakar Plateau             189486               14.7
#
#                            Communes d'arrondissement
# 0          Mermoz . Sacré-Coeur . Ngor . Ouakam-Yoff
# 1  Dakar-Plateau . Fann . PointE . Amitie-Geule-T...

# %%
result[2:]
# Out:
#         Arrondissement  Poulation en 2013  Superficie en Km2  \
# 2          Grand Dakar             306728               18.9
# 3  Parcelles Assainies             438527               14.7
#
#                            Communes d'arrondissement
# 2  Biscuiterie . Dieupeul . Derklé . Grand-Dakar ...
# 3  Camberene . Grand-Yoff . Parcelles-Assainies ....

# %%
df1 = pd.read_csv('D:/Jeu de données/Edacy/Pandas/nba-2.csv')

# %%
df1[::2]
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# ...

# %%
df1[::-1]
# Out:
#                         Name                    Team  Number Position   Age  \
# 457                      NaN                     NaN     NaN      NaN   NaN
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
# 455             Tibor Pleiss               Utah Jazz    21.0        C  26.0
# 454                Raul Neto               Utah Jazz    25.0       PG  24.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 450               Joe Ingles               Utah Jazz     2.0       SF  28.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 447              Rudy Gobert               Utah Jazz    27.0        C  23.0
# ...

# %%
result.loc[0]
# Out:
# Arrondissement                                                Almadies
# Poulation en 2013                                               211315
# Superficie en Km2                                                 30.1
# Communes d'arrondissement    Mermoz . Sacré-Coeur . Ngor . Ouakam-Yoff
# Name: 0, dtype: object

# %%
df2 = pd.read_csv('D:/Jeu de données/Edacy/Pandas/nba-2.csv', index_col = 0)

# %%
df2
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
df2.loc['Avery Bradley']
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: Avery Bradley, dtype: object

# %%
df2.loc[['Avery Bradley', 'Jae Crowder', 'Tibor Pleiss']]
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
#
#                  College     Salary
# Name
# Avery Bradley      Texas  7730337.0
# Jae Crowder    Marquette  6796117.0
# Tibor Pleiss         NaN  2900000.0

# %%
df2.loc['Avery Bradley' : 'Brook Lopez']
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley            Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder              Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland             Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter              Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko            Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson             Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey            Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk             Boston Celtics    41.0        C  25.0    7-0   238.0
# Terry Rozier             Boston Celtics    12.0       PG  22.0    6-2   190.0
# Marcus Smart             Boston Celtics    36.0       PG  22.0    6-4   220.0
# Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9   260.0
# ...
